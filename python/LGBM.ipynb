# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import pandas as pd

from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score
import lightgbm as lgb

import warnings
warnings.filterwarnings('ignore')

data_dir = "../Data/"

def rmsle(val, pred):
    return np.sqrt(np.mean(np.power(np.log(val+1)-np.log(pred+1), 2)))

rmsle_score = make_scorer(rmsle, greater_is_better=False)

# %%
train_df = pd.read_csv(data_dir+"train.csv")
test_df = pd.read_csv(data_dir+"test.csv")

# %%
#https://www.kaggle.com/samratp/lightgbm-xgboost-catboost
X_train = train_df.drop(["ID", "target"], axis=1)
y_train = np.log(train_df["target"].values +1)

X_test = test_df.drop(["ID"], axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
dev_X, val_X, dev_y, val_y = train_test_split(X_train, y_train, test_size = 0.1, random_state = 42)

# %%
def run_lgb(train_X, train_y, val_X, val_y, test_X):
    params = {
        "objective" : "regression",
        "metric" : "rmse",
        "num_leaves" : 40,
        "learning_rate" : 0.0025,
        "bagging_fraction" : 0.7,
        "feature_fraction" : 0.5,
        "bagging_frequency" : 5,
        "bagging_seed" : 42,
        "verbosity" : -1,
        "seed": 42
    }
    
    lgtrain = lgb.Dataset(train_X, label=train_y)
    lgval = lgb.Dataset(val_X, label=val_y)
    evals_result = {}
    model = lgb.train(params, lgtrain, 10000, 
                      valid_sets=[lgval], 
                      early_stopping_rounds=500, 
                      verbose_eval=50, 
                      evals_result=evals_result)
    
    pred_test_y = np.expm1(model.predict(test_X, num_iteration=model.best_iteration))
    return pred_test_y, model, evals_result

# %%
red_test, model, evals_result = run_lgb(dev_X, dev_y, val_X, val_y, X_test)
print("LightGBM Training Completed...")
# Out:
# Training until validation scores don't improve for 500 rounds.
# [50]	valid_0's rmse: 1.64311
# [100]	valid_0's rmse: 1.60888
# [150]	valid_0's rmse: 1.57975
# [200]	valid_0's rmse: 1.5555
# [250]	valid_0's rmse: 1.53453
# [300]	valid_0's rmse: 1.51733
# [350]	valid_0's rmse: 1.50249
# [400]	valid_0's rmse: 1.48962
# [450]	valid_0's rmse: 1.47907
# [500]	valid_0's rmse: 1.47034
# [550]	valid_0's rmse: 1.46215
# [600]	valid_0's rmse: 1.4558
# [650]	valid_0's rmse: 1.44974
# [700]	valid_0's rmse: 1.44496
# [750]	valid_0's rmse: 1.44039
# [800]	valid_0's rmse: 1.4373
# [850]	valid_0's rmse: 1.4342
# [900]	valid_0's rmse: 1.43152
# [950]	valid_0's rmse: 1.42964
# [1000]	valid_0's rmse: 1.42802
# [1050]	valid_0's rmse: 1.42682
# [1100]	valid_0's rmse: 1.42581
# [1150]	valid_0's rmse: 1.42443
# [1200]	valid_0's rmse: 1.42365
# [1250]	valid_0's rmse: 1.42309
# [1300]	valid_0's rmse: 1.42267
# [1350]	valid_0's rmse: 1.42178
# [1400]	valid_0's rmse: 1.4211
# [1450]	valid_0's rmse: 1.42085
# [1500]	valid_0's rmse: 1.42053
# [1550]	valid_0's rmse: 1.42055
# [1600]	valid_0's rmse: 1.42047
# [1650]	valid_0's rmse: 1.42009
# [1700]	valid_0's rmse: 1.42025
# [1750]	valid_0's rmse: 1.41987
# [1800]	valid_0's rmse: 1.41982
# [1850]	valid_0's rmse: 1.41986
# [1900]	valid_0's rmse: 1.42014
# [1950]	valid_0's rmse: 1.4201
# [2000]	valid_0's rmse: 1.42071
# [2050]	valid_0's rmse: 1.42046
# [2100]	valid_0's rmse: 1.42083
# [2150]	valid_0's rmse: 1.42077
# [2200]	valid_0's rmse: 1.42115
# [2250]	valid_0's rmse: 1.42128
# [2300]	valid_0's rmse: 1.42144
# Early stopping, best iteration is:
# [1824]	valid_0's rmse: 1.41969
# LightGBM Training Completed...

# %%
from sklearn.cross_validation import KFold

# %%
#https://www.kaggle.com/rooshroosh/lightgbm-baseline-1-49-lb
train_df = pd.read_csv(data_dir+"train.csv")
test_df = pd.read_csv(data_dir+"test.csv")

# %%
train=train_df
test=test_df

# %%
Y = np.log(train.target+1)

train.drop(['target'], axis=1, inplace=True)

test_ID = test.ID
test.drop(['ID'], axis=1, inplace=True)

train_ID = train.ID
train.drop(['ID'], axis=1, inplace=True)

# %%
lgbm_params =  {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': 'rmse',
    'max_depth': 12,
    'num_leaves': 63,  #  127, 255
    'feature_fraction': 0.8,   # 0.1, 0.01
    'bagging_fraction': 0.8,
    'learning_rate': 0.0025,
    'verbose': 1
}

# %%
import time

# %%
Y_target = []
for fold_id,(train_idx, val_idx) in enumerate(KFold(n=train.shape[0], n_folds=10, random_state=42)):
    print('FOLD:',fold_id)
    X_train = train.values[train_idx]
    y_train = Y.values[train_idx]
    X_valid = train.values[val_idx]
    y_valid =  Y.values[val_idx]
    
    
    lgtrain = lgb.Dataset(X_train, y_train,
                feature_name=train.columns.tolist(),
    #             categorical_feature = categorical
                         )

    lgvalid = lgb.Dataset(X_valid, y_valid,
                feature_name=train.columns.tolist(),
    #             categorical_feature = categorical
                         )

    modelstart = time.time()
    lgb_clf = lgb.train(
        lgbm_params,
        lgtrain,
        num_boost_round=30000,
        valid_sets=[lgtrain, lgvalid],
        valid_names=['train','valid'],
        early_stopping_rounds=100,
        verbose_eval=100
    )
    
    test_pred = lgb_clf.predict(test.values)
    Y_target.append(np.exp(test_pred)-1)
    print('fold finish after', time.time()-modelstart)
# Out:
# FOLD: 0
# Training until validation scores don't improve for 100 rounds.
# [100]	train's rmse: 1.63075	valid's rmse: 1.61858
# [200]	train's rmse: 1.52952	valid's rmse: 1.56752
# [300]	train's rmse: 1.44766	valid's rmse: 1.52678
# [400]	train's rmse: 1.38077	valid's rmse: 1.49704
# [500]	train's rmse: 1.32384	valid's rmse: 1.47317
# [600]	train's rmse: 1.27541	valid's rmse: 1.45664
# [700]	train's rmse: 1.23466	valid's rmse: 1.44541
# [800]	train's rmse: 1.20297	valid's rmse: 1.43717
# [900]	train's rmse: 1.17394	valid's rmse: 1.43045
# [1000]	train's rmse: 1.14989	valid's rmse: 1.42596
# [1100]	train's rmse: 1.12874	valid's rmse: 1.42342
# [1200]	train's rmse: 1.11097	valid's rmse: 1.4208
# [1300]	train's rmse: 1.09689	valid's rmse: 1.41854
# [1400]	train's rmse: 1.08352	valid's rmse: 1.4157
# [1500]	train's rmse: 1.07161	valid's rmse: 1.41345
# [1600]	train's rmse: 1.06085	valid's rmse: 1.41177
# [1700]	train's rmse: 1.05035	valid's rmse: 1.40958
# [1800]	train's rmse: 1.04073	valid's rmse: 1.40791
# [1900]	train's rmse: 1.03195	valid's rmse: 1.40641
# [2000]	train's rmse: 1.02357	valid's rmse: 1.40501
# [2100]	train's rmse: 1.01543	valid's rmse: 1.40385
# [2200]	train's rmse: 1.00746	valid's rmse: 1.40268
# [2300]	train's rmse: 0.999553	valid's rmse: 1.40122
# [2400]	train's rmse: 0.992543	valid's rmse: 1.40035
# [2500]	train's rmse: 0.985737	valid's rmse: 1.39983
# [2600]	train's rmse: 0.979288	valid's rmse: 1.39913
# [2700]	train's rmse: 0.972759	valid's rmse: 1.39835
# [2800]	train's rmse: 0.966681	valid's rmse: 1.39772
# [2900]	train's rmse: 0.961037	valid's rmse: 1.39721
# [3000]	train's rmse: 0.955406	valid's rmse: 1.39684
# [3100]	train's rmse: 0.949553	valid's rmse: 1.39653
# [3200]	train's rmse: 0.94277	valid's rmse: 1.39628
# [3300]	train's rmse: 0.93733	valid's rmse: 1.39644
# Early stopping, best iteration is:
# [3203]	train's rmse: 0.942578	valid's rmse: 1.39625
# fold finish after 128.06042075157166
# FOLD: 1
# Training until validation scores don't improve for 100 rounds.
# [100]	train's rmse: 1.62798	valid's rmse: 1.64111
# [200]	train's rmse: 1.52765	valid's rmse: 1.57958
# [300]	train's rmse: 1.44674	valid's rmse: 1.53562
# [400]	train's rmse: 1.38016	valid's rmse: 1.50574
# [500]	train's rmse: 1.32475	valid's rmse: 1.48215
# [600]	train's rmse: 1.27802	valid's rmse: 1.46411
# [700]	train's rmse: 1.23748	valid's rmse: 1.45196
# [800]	train's rmse: 1.20181	valid's rmse: 1.44252
# [900]	train's rmse: 1.17208	valid's rmse: 1.43599
# [1000]	train's rmse: 1.14577	valid's rmse: 1.43097
# [1100]	train's rmse: 1.12428	valid's rmse: 1.42744
# [1200]	train's rmse: 1.10715	valid's rmse: 1.42566
# [1300]	train's rmse: 1.09369	valid's rmse: 1.42427
# [1400]	train's rmse: 1.08105	valid's rmse: 1.42337
# [1500]	train's rmse: 1.07012	valid's rmse: 1.42224
# [1600]	train's rmse: 1.06031	valid's rmse: 1.4214
# [1700]	train's rmse: 1.05064	valid's rmse: 1.42126
# [1800]	train's rmse: 1.04167	valid's rmse: 1.421
# [1900]	train's rmse: 1.0326	valid's rmse: 1.42066
# [2000]	train's rmse: 1.02414	valid's rmse: 1.42048
# [2100]	train's rmse: 1.01643	valid's rmse: 1.42047
# [2200]	train's rmse: 1.00843	valid's rmse: 1.4202
# [2300]	train's rmse: 1.0007	valid's rmse: 1.41961
# [2400]	train's rmse: 0.993961	valid's rmse: 1.41932
# [2500]	train's rmse: 0.987072	valid's rmse: 1.41938
# Early stopping, best iteration is:
# [2445]	train's rmse: 0.99062	valid's rmse: 1.41908
# fold finish after 104.57826447486877
# FOLD: 2
# Training until validation scores don't improve for 100 rounds.
# [100]	train's rmse: 1.62456	valid's rmse: 1.6746
# [200]	train's rmse: 1.5255	valid's rmse: 1.61815
# [300]	train's rmse: 1.44427	valid's rmse: 1.58067
# [400]	train's rmse: 1.37709	valid's rmse: 1.55257
# [500]	train's rmse: 1.32038	valid's rmse: 1.53152
# [600]	train's rmse: 1.27302	valid's rmse: 1.51636
# [700]	train's rmse: 1.23149	valid's rmse: 1.50564
# [800]	train's rmse: 1.19737	valid's rmse: 1.49977
# [900]	train's rmse: 1.16941	valid's rmse: 1.49675
# [1000]	train's rmse: 1.14665	valid's rmse: 1.49416
# [1100]	train's rmse: 1.12643	valid's rmse: 1.49312
# [1200]	train's rmse: 1.10928	valid's rmse: 1.4925
# [1300]	train's rmse: 1.09445	valid's rmse: 1.49308
# Early stopping, best iteration is:
# [1223]	train's rmse: 1.10563	valid's rmse: 1.49237
# fold finish after 67.60751104354858
# FOLD: 3
# Training until validation scores don't improve for 100 rounds.
# [100]	train's rmse: 1.62165	valid's rmse: 1.70549
# [200]	train's rmse: 1.52354	valid's rmse: 1.64432
# [300]	train's rmse: 1.44326	valid's rmse: 1.5978
# [400]	train's rmse: 1.37733	valid's rmse: 1.56495
# [500]	train's rmse: 1.32205	valid's rmse: 1.54329
# [600]	train's rmse: 1.27515	valid's rmse: 1.52628
# [700]	train's rmse: 1.23533	valid's rmse: 1.51446
# [800]	train's rmse: 1.20172	valid's rmse: 1.50519
# [900]	train's rmse: 1.17194	valid's rmse: 1.49839
# [1000]	train's rmse: 1.148	valid's rmse: 1.49249
# [1100]	train's rmse: 1.12722	valid's rmse: 1.4878
# [1200]	train's rmse: 1.10998	valid's rmse: 1.4842
# [1300]	train's rmse: 1.0959	valid's rmse: 1.48135
# [1400]	train's rmse: 1.08345	valid's rmse: 1.47984
# [1500]	train's rmse: 1.07144	valid's rmse: 1.47823
# [1600]	train's rmse: 1.05987	valid's rmse: 1.47669
# [1700]	train's rmse: 1.04956	valid's rmse: 1.47583
# [1800]	train's rmse: 1.04065	valid's rmse: 1.47488
# [1900]	train's rmse: 1.03236	valid's rmse: 1.47399
# [2000]	train's rmse: 1.02447	valid's rmse: 1.47321
# [2100]	train's rmse: 1.01574	valid's rmse: 1.47233
# [2200]	train's rmse: 1.00772	valid's rmse: 1.47056
# [2300]	train's rmse: 1.00092	valid's rmse: 1.46954
# [2400]	train's rmse: 0.993096	valid's rmse: 1.46886
# [2500]	train's rmse: 0.985354	valid's rmse: 1.4686
# [2600]	train's rmse: 0.978036	valid's rmse: 1.46823
# [2700]	train's rmse: 0.970734	valid's rmse: 1.46744
# [2800]	train's rmse: 0.963906	valid's rmse: 1.46675
# [2900]	train's rmse: 0.957875	valid's rmse: 1.46627
# [3000]	train's rmse: 0.951634	valid's rmse: 1.46623
# [3100]	train's rmse: 0.945859	valid's rmse: 1.46561
# [3200]	train's rmse: 0.940011	valid's rmse: 1.46544
# [3300]	train's rmse: 0.934644	valid's rmse: 1.46534
# [3400]	train's rmse: 0.929192	valid's rmse: 1.4651
# [3500]	train's rmse: 0.924235	valid's rmse: 1.46495
# [3600]	train's rmse: 0.91901	valid's rmse: 1.46455
# [3700]	train's rmse: 0.914328	valid's rmse: 1.46441
# Early stopping, best iteration is:
# [3686]	train's rmse: 0.915039	valid's rmse: 1.46438
# fold finish after 144.28423380851746
# FOLD: 4
# Training until validation scores don't improve for 100 rounds.
# [100]	train's rmse: 1.6303	valid's rmse: 1.63182
# [200]	train's rmse: 1.53158	valid's rmse: 1.56002
# [300]	train's rmse: 1.45163	valid's rmse: 1.50834
# [400]	train's rmse: 1.38489	valid's rmse: 1.47108
# [500]	train's rmse: 1.32926	valid's rmse: 1.4424
# [600]	train's rmse: 1.28395	valid's rmse: 1.42272
# [700]	train's rmse: 1.24476	valid's rmse: 1.40696
# [800]	train's rmse: 1.21118	valid's rmse: 1.39373
# [900]	train's rmse: 1.18223	valid's rmse: 1.38424
# [1000]	train's rmse: 1.15759	valid's rmse: 1.37781
# [1100]	train's rmse: 1.13617	valid's rmse: 1.37434
# [1200]	train's rmse: 1.11791	valid's rmse: 1.37172
# [1300]	train's rmse: 1.10194	valid's rmse: 1.36897
# [1400]	train's rmse: 1.08869	valid's rmse: 1.36762
# [1500]	train's rmse: 1.07675	valid's rmse: 1.36633
# [1600]	train's rmse: 1.06538	valid's rmse: 1.36579
# [1700]	train's rmse: 1.05523	valid's rmse: 1.36499
# [1800]	train's rmse: 1.04588	valid's rmse: 1.36485
# [1900]	train's rmse: 1.03748	valid's rmse: 1.36468
# [2000]	train's rmse: 1.0287	valid's rmse: 1.36436
# [2100]	train's rmse: 1.02046	valid's rmse: 1.36432
# Early stopping, best iteration is:
# [2080]	train's rmse: 1.02205	valid's rmse: 1.3641
# fold finish after 92.92251515388489
# FOLD: 5
# Training until validation scores don't improve for 100 rounds.
# [100]	train's rmse: 1.63022	valid's rmse: 1.62394
# [200]	train's rmse: 1.53218	valid's rmse: 1.55381
# [300]	train's rmse: 1.45091	valid's rmse: 1.50333
# [400]	train's rmse: 1.38378	valid's rmse: 1.46732
# [500]	train's rmse: 1.32776	valid's rmse: 1.44166
# [600]	train's rmse: 1.28116	valid's rmse: 1.42096
# [700]	train's rmse: 1.23992	valid's rmse: 1.40493
# [800]	train's rmse: 1.20584	valid's rmse: 1.39399
# [900]	train's rmse: 1.17601	valid's rmse: 1.38525
# [1000]	train's rmse: 1.15166	valid's rmse: 1.3791
# [1100]	train's rmse: 1.13224	valid's rmse: 1.37429
# [1200]	train's rmse: 1.11558	valid's rmse: 1.37065
# [1300]	train's rmse: 1.10111	valid's rmse: 1.36733
# [1400]	train's rmse: 1.08804	valid's rmse: 1.36551
# [1500]	train's rmse: 1.07644	valid's rmse: 1.36325
# [1600]	train's rmse: 1.06474	valid's rmse: 1.3614
# [1700]	train's rmse: 1.05552	valid's rmse: 1.36002
# [1800]	train's rmse: 1.04604	valid's rmse: 1.35825
# [1900]	train's rmse: 1.03721	valid's rmse: 1.35754
# [2000]	train's rmse: 1.02836	valid's rmse: 1.35723
# [2100]	train's rmse: 1.02077	valid's rmse: 1.35716
# [2200]	train's rmse: 1.01316	valid's rmse: 1.35705
# [2300]	train's rmse: 1.00585	valid's rmse: 1.35691
# [2400]	train's rmse: 0.999138	valid's rmse: 1.35687
# [2500]	train's rmse: 0.992781	valid's rmse: 1.35693
# Early stopping, best iteration is:
# [2413]	train's rmse: 0.998381	valid's rmse: 1.3567
# fold finish after 103.0801510810852
# FOLD: 6
# Training until validation scores don't improve for 100 rounds.
# [100]	train's rmse: 1.62741	valid's rmse: 1.65445
# [200]	train's rmse: 1.5284	valid's rmse: 1.59198
# [300]	train's rmse: 1.44731	valid's rmse: 1.54628
# [400]	train's rmse: 1.38107	valid's rmse: 1.51369
# [500]	train's rmse: 1.32657	valid's rmse: 1.49114
# [600]	train's rmse: 1.27885	valid's rmse: 1.47273
# [700]	train's rmse: 1.23929	valid's rmse: 1.45832
# [800]	train's rmse: 1.20524	valid's rmse: 1.44694
# [900]	train's rmse: 1.17668	valid's rmse: 1.43729
# [1000]	train's rmse: 1.15299	valid's rmse: 1.43083
# [1100]	train's rmse: 1.13299	valid's rmse: 1.42576
# [1200]	train's rmse: 1.11547	valid's rmse: 1.42204
# [1300]	train's rmse: 1.10109	valid's rmse: 1.42005
# [1400]	train's rmse: 1.08797	valid's rmse: 1.41777
# [1500]	train's rmse: 1.07604	valid's rmse: 1.41582
# [1600]	train's rmse: 1.0648	valid's rmse: 1.41456
# [1700]	train's rmse: 1.05451	valid's rmse: 1.41311
# [1800]	train's rmse: 1.04506	valid's rmse: 1.41186
# [1900]	train's rmse: 1.035	valid's rmse: 1.411
# [2000]	train's rmse: 1.026	valid's rmse: 1.41033
# [2100]	train's rmse: 1.01802	valid's rmse: 1.40987
# [2200]	train's rmse: 1.01032	valid's rmse: 1.40928
# [2300]	train's rmse: 1.00243	valid's rmse: 1.40908
# [2400]	train's rmse: 0.994854	valid's rmse: 1.4084
# [2500]	train's rmse: 0.98785	valid's rmse: 1.40801
# [2600]	train's rmse: 0.980576	valid's rmse: 1.40821
# Early stopping, best iteration is:
# [2523]	train's rmse: 0.98627	valid's rmse: 1.40788
# fold finish after 107.5193030834198
# FOLD: 7
# Training until validation scores don't improve for 100 rounds.
# [100]	train's rmse: 1.62985	valid's rmse: 1.63745
# [200]	train's rmse: 1.52933	valid's rmse: 1.59083
# [300]	train's rmse: 1.44601	valid's rmse: 1.55658
# [400]	train's rmse: 1.37822	valid's rmse: 1.53222
# [500]	train's rmse: 1.3235	valid's rmse: 1.51175
# [600]	train's rmse: 1.27747	valid's rmse: 1.49772
# [700]	train's rmse: 1.23637	valid's rmse: 1.48635
# [800]	train's rmse: 1.20276	valid's rmse: 1.47738
# [900]	train's rmse: 1.1749	valid's rmse: 1.47146
# [1000]	train's rmse: 1.15097	valid's rmse: 1.46651
# [1100]	train's rmse: 1.13088	valid's rmse: 1.46362
# [1200]	train's rmse: 1.11244	valid's rmse: 1.46125
# [1300]	train's rmse: 1.09763	valid's rmse: 1.45919
# [1400]	train's rmse: 1.08463	valid's rmse: 1.45781
# [1500]	train's rmse: 1.07259	valid's rmse: 1.45647
# [1600]	train's rmse: 1.0619	valid's rmse: 1.45551
# [1700]	train's rmse: 1.05172	valid's rmse: 1.45481
# [1800]	train's rmse: 1.04219	valid's rmse: 1.45426
# [1900]	train's rmse: 1.03443	valid's rmse: 1.45439
# Early stopping, best iteration is:
# [1825]	train's rmse: 1.0403	valid's rmse: 1.45404
# fold finish after 90.96760582923889
# FOLD: 8
# Training until validation scores don't improve for 100 rounds.
# [100]	train's rmse: 1.61378	valid's rmse: 1.78359
# [200]	train's rmse: 1.51491	valid's rmse: 1.73133
# [300]	train's rmse: 1.434	valid's rmse: 1.69498
# [400]	train's rmse: 1.36764	valid's rmse: 1.66716
# [500]	train's rmse: 1.31257	valid's rmse: 1.64656
# [600]	train's rmse: 1.26644	valid's rmse: 1.6318
# [700]	train's rmse: 1.22677	valid's rmse: 1.61993
# [800]	train's rmse: 1.19367	valid's rmse: 1.6103
# [900]	train's rmse: 1.16508	valid's rmse: 1.60248
# [1000]	train's rmse: 1.14113	valid's rmse: 1.59645
# [1100]	train's rmse: 1.12275	valid's rmse: 1.59304
# [1200]	train's rmse: 1.10516	valid's rmse: 1.58973
# [1300]	train's rmse: 1.08939	valid's rmse: 1.5875
# [1400]	train's rmse: 1.07675	valid's rmse: 1.58528
# [1500]	train's rmse: 1.06531	valid's rmse: 1.58333
# [1600]	train's rmse: 1.05385	valid's rmse: 1.5819
# [1700]	train's rmse: 1.04311	valid's rmse: 1.58079
# [1800]	train's rmse: 1.0339	valid's rmse: 1.58001
# [1900]	train's rmse: 1.02471	valid's rmse: 1.579
# [2000]	train's rmse: 1.01602	valid's rmse: 1.57783
# [2100]	train's rmse: 1.0073	valid's rmse: 1.5769
# [2200]	train's rmse: 0.999533	valid's rmse: 1.5762
# [2300]	train's rmse: 0.992057	valid's rmse: 1.57575
# [2400]	train's rmse: 0.984701	valid's rmse: 1.57526
# [2500]	train's rmse: 0.978143	valid's rmse: 1.5744
# [2600]	train's rmse: 0.971768	valid's rmse: 1.57364
# [2700]	train's rmse: 0.965267	valid's rmse: 1.57289
# [2800]	train's rmse: 0.959205	valid's rmse: 1.57254
# [2900]	train's rmse: 0.953492	valid's rmse: 1.57194
# [3000]	train's rmse: 0.948256	valid's rmse: 1.57132
# [3100]	train's rmse: 0.942484	valid's rmse: 1.5707
# [3200]	train's rmse: 0.937089	valid's rmse: 1.57038
# [3300]	train's rmse: 0.932185	valid's rmse: 1.56995
# [3400]	train's rmse: 0.927157	valid's rmse: 1.56967
# [3500]	train's rmse: 0.922098	valid's rmse: 1.56926
# [3600]	train's rmse: 0.916756	valid's rmse: 1.56885
# [3700]	train's rmse: 0.911955	valid's rmse: 1.56865
# [3800]	train's rmse: 0.90704	valid's rmse: 1.568
# [3900]	train's rmse: 0.902202	valid's rmse: 1.56766
# [4000]	train's rmse: 0.897408	valid's rmse: 1.56748
# [4100]	train's rmse: 0.892548	valid's rmse: 1.56736
# [4200]	train's rmse: 0.888205	valid's rmse: 1.56733
# Early stopping, best iteration is:
# [4113]	train's rmse: 0.891894	valid's rmse: 1.56725
# fold finish after 167.10090136528015
# FOLD: 9
# Training until validation scores don't improve for 100 rounds.
# [100]	train's rmse: 1.62269	valid's rmse: 1.70074
# [200]	train's rmse: 1.52513	valid's rmse: 1.63448
# [300]	train's rmse: 1.44296	valid's rmse: 1.58556
# [400]	train's rmse: 1.37661	valid's rmse: 1.54718
# [500]	train's rmse: 1.32158	valid's rmse: 1.51664
# [600]	train's rmse: 1.27249	valid's rmse: 1.49572
# [700]	train's rmse: 1.23266	valid's rmse: 1.48093
# [800]	train's rmse: 1.19971	valid's rmse: 1.46946
# [900]	train's rmse: 1.17292	valid's rmse: 1.46036
# [1000]	train's rmse: 1.1481	valid's rmse: 1.45269
# [1100]	train's rmse: 1.12656	valid's rmse: 1.44619
# [1200]	train's rmse: 1.10727	valid's rmse: 1.44074
# [1300]	train's rmse: 1.09443	valid's rmse: 1.43752
# [1400]	train's rmse: 1.08179	valid's rmse: 1.4358
# [1500]	train's rmse: 1.06908	valid's rmse: 1.43396
# [1600]	train's rmse: 1.0578	valid's rmse: 1.43258
# [1700]	train's rmse: 1.0473	valid's rmse: 1.43149
# [1800]	train's rmse: 1.03681	valid's rmse: 1.4303
# [1900]	train's rmse: 1.02728	valid's rmse: 1.4288
# [2000]	train's rmse: 1.01884	valid's rmse: 1.42826
# [2100]	train's rmse: 1.01079	valid's rmse: 1.42744
# [2200]	train's rmse: 1.00263	valid's rmse: 1.42635
# [2300]	train's rmse: 0.995468	valid's rmse: 1.42541
# [2400]	train's rmse: 0.98838	valid's rmse: 1.42479
# [2500]	train's rmse: 0.982112	valid's rmse: 1.42456
# [2600]	train's rmse: 0.974767	valid's rmse: 1.42381
# [2700]	train's rmse: 0.968675	valid's rmse: 1.42338
# [2800]	train's rmse: 0.962441	valid's rmse: 1.42294
# [2900]	train's rmse: 0.955849	valid's rmse: 1.42293
# Early stopping, best iteration is:
# [2832]	train's rmse: 0.959983	valid's rmse: 1.42278
# fold finish after 127.68432188034058

# %%
Y_target = np.array(Y_target)

sub = pd.read_csv(data_dir+'/sample_submission.csv')
sub['target'] = Y_target.mean(axis=0)
sub.to_csv('sub_lgb_test.csv', index=False)
